# %%
# %load_ext autoreload
# %autoreload 2

from publication.figure_01 import (
    plot_sequence_order,
    plot_selected_sound,
    plot_example_quantifications
)

from publication.figure_02 import (
    print_percentage_significant,
    plot_duration_vs_amplitude_scatter,
    print_metrics_by_classification,
    plot_all_context_pairs_grid,
    plot_metric_by_categories_comparisons,
    print_multivariate_linear_regressions,
    plot_metric_by_probe_vocalization,
    print_probe_voc_regression,
)

from publication.figure_03 import (
    plot_example_site_coverage,
    plot_neuron_and_site_coverage_summary,
)

from publication.figure_04 import (
    plot_example_coverage_with_diagonalization,
    plot_diagonalization_geometric_example,
    plot_summary_decoder_accuracies,
    plot_decoder_analysis_by_nsounds_and_region,
    plot_simple_psht_with_avg,
)

from publication.figure_05 import (
    plot_optotagged_example_neuron,
    plot_classified_waveforms,
    plot_cell_type_distributions,
    plot_metric_cumulative_histograms,
    plot_metric_insets,
    plot_coverage_cumulative_histogram,
    plot_coverage_inset,
)

from publication.figure_06 import (
    plot_encoding_model_schematic,
    plot_example_model_predictions,
    plot_relative_model_performances,
    plot_context_effect_prediction_scatter,
    plot_summary_model_performance_bars,
    plot_absolute_model_performances,
)

from publication.table_01 import create_sound_analysis_table

from publication.sup_figure_01 import (
    plot_context_metric_correlation_significance,
    plot_layer_effect_on_context_metrics
)

from publication.sup_figure_02 import (
    plot_exmaple_pupil_psths, 
    plot_first_vs_second_order_effects,
    plot_sound_effect_on_pupil,
    print_sound_metrics_correlation_to_pupil
)

from publication.sup_figure_03 import (
    plot_cumulative_variances_explained,
    plot_example_pca_coverages
)

from publication.sup_figure_06 import (
    plot_connection_weigths_by_cell_type, 
    plot_strf_average_weights_over_time,
    print_self_weights_statistics
)
# Out:
# [nems.configs.defaults INFO] Saving log messages to /tmp/nems/NEMS 2023-10-31 133115.log
# cannot connect to database, loading hardcoded sites
# cannot connect to database, loading hardcoded A1_cells, PEG_cells and all_cells sets
# 1006 selected A1 good isolation cells
# 716 selected PEG good isolation cells
# 1722 selected total good isolation cells
# cannot connect to database, loading hardcoded cellid_A1_fit_set and cellid_PEG_fit_set sets.
# 233 A1 cells for model fitting
# 88 PEG cells for model fitting
# cannot connect to database, loading hardcoded dictionary mappingcellids to region associated batch number
# ['A1 contains 1603 cells', 'PEG contains 1143 cells']
# found and loaded working data frame from cache
# found and loaded pupil effects working data frame from cache
# DF cache found, reloading
# ####
# found and loaded cache for ARM021b
# ####
# found and loaded cache for ARM021b
# found cache at /home/mateo/code/context_probe_analysis/data/230921_metric_correlations, loading...
# ...done
# no cache for site ley072b
# no cache for site ley070a
# no cache for site ley075b
# cache found, loading dataframe containing all model connection weights
# cache found, loading dataframe containing time STRF weights

# %% [markdown]
# The purpose of this notebooks is as a quick visual reference
# to find what code produces each one of the figures.
# It is not meant to be run to generate all the intermediate
# analysis and checkpoints, and it will probably break if that
# is done.
# If you dont wanna lose the pressent figures, avoid re-running
# unless you have already run the main.py script which does regenerate
#  all the relevant caches and dataframes.
#  # Figure 0, Graphical abstract
#  ## left panel

# %%
fig = plot_simple_psht_with_avg()
fig.show(renderer='jpeg', scale=1)

# %% [markdown]
# # Figure 1
# ## panel A

# %%
fig = plot_sequence_order()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel C

# %%
fig = plot_selected_sound()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panels D to k

# %%
fig = plot_example_quantifications()
fig.show(renderer='jpeg', scale=2)
# Out:
# using t-score threshold for sample-alpha 0.05 -> t = 2.024394164575136
# integral: 0.559 Z-score*s
# center of mass: 150.75 ms
# last bin: 450.00 ms
# using t-score threshold for sample-alpha 0.05 -> t = 2.024394164575136
# integral: 1.508 Z-score*s
# center of mass: 352.31 ms
# last bin: 900.00 ms

# %% [markdown]
# # Figure 2
# ## panel A

# %%
print_percentage_significant()
fig = plot_duration_vs_amplitude_scatter()
fig.show(renderer='jpeg', scale=2)
# Out:
# 45906/501440, 9.155% significant  instances
# 1232/1722, 71.545% modulated neurons
#         inst_count  neu_count
# region
# A1           24711        709
# PEG          21195        523
#
#                inst_count  neu_count
# trans_pair
# same_silence        1766        725
# diff_silence       11242       1019
# diff_same           7657        945
# diff_diff          25241        991
# ######## full dataset metrics ########
# LinregressResult(slope=0.00043606027794971034, intercept=0.12776281544795312, rvalue=0.47971149300071986, pvalue=0.0, stderr=3.7226463308916435e-06, intercept_stderr=0.001210202309347121)
# time saturated instances: n=667, %=1.4529691107916176
# metric      integral      last_bin
# count   45906.000000  45906.000000
# mean        0.236450    249.250641
# std         0.189718    208.706192
# min         0.023983     50.000000
# 25%         0.120628    100.000000
# 50%         0.181853    200.000000
# 75%         0.285334    300.000000
# max         2.916471   1000.000000

# %% [markdown]
# ## panel B

# %%
fig = plot_all_context_pairs_grid()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# # panels E to H

# %%
print_metrics_by_classification()
print_multivariate_linear_regressions()
fig = plot_metric_by_categories_comparisons()
fig.show(renderer='jpeg', scale=2)
# Out:
# ##### mean and error values by region #####
# integral mean±SEM. A1: 0.23±0.001, PEG: 0.25±0.001Z-score*s
# last_bin mean±SEM. A1: 244.97±1.357, PEG: 254.25±1.396ms
#
# ##### mean and error values by vocalization #####
# integral mean±SEM. sound: 0.22±0.0010, vocalization: 0.24±0.0020 Z-score*s
# last_bin mean±SEM. sound: 229.37±1.2012, vocalization: 252.92±2.3301 ms
#
# ##### mean and error values by transition #####
# integral mean±SEM. diff: 0.24±0.0009, same: 0.23±0.0018, silence: 0.28±0.0022 Z-score*s
# last_bin mean±SEM. diff: 247.83±0.9858, same: 246.92±2.1641, silence: 287.33±2.1618 ms
#
# ############## Multivariate linear regression models ##############
# ####### by region #######
#
#
# #### integral ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     149.2
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):           2.95e-34
# Time:                        13:31:34   Log-Likelihood:                -54954.
# No. Observations:               45906   AIC:                         1.099e+05
# Df Residuals:                   45904   BIC:                         1.099e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.9577      0.005    187.936      0.000       0.948       0.968
# C(region)[T.PEG]     0.0916      0.007     12.214      0.000       0.077       0.106
# ==============================================================================
# Omnibus:                    32458.974   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           677833.953
# Skew:                           3.183   Prob(JB):                         0.00
# Kurtosis:                      20.716   Cond. No.                         2.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# #### last_bin ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     22.57
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):           2.03e-06
# Time:                        13:31:34   Log-Likelihood:                -56977.
# No. Observations:               45906   AIC:                         1.140e+05
# Df Residuals:                   45904   BIC:                         1.140e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.9828      0.005    184.548      0.000       0.972       0.993
# C(region)[T.PEG]     0.0372      0.008      4.751      0.000       0.022       0.053
# ==============================================================================
# Omnibus:                    13924.843   Durbin-Watson:                   1.535
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35145.684
# Skew:                           1.686   Prob(JB):                         0.00
# Kurtosis:                       5.645   Cond. No.                         2.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ####### by context type and vocalization #######
#
#
# #### integral ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     94.74
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):          8.62e-100
# Time:                        13:31:34   Log-Likelihood:                -82558.
# No. Observations:               66571   AIC:                         1.651e+05
# Df Residuals:                   66565   BIC:                         1.652e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.9922      0.004    224.563      0.000       0.984       1.001
# C(voc_ctx)[T.vocalization]                              0.0208      0.010      2.045      0.041       0.001       0.041
# C(transition)[T.same]                                  -0.0404      0.011     -3.793      0.000      -0.061      -0.020
# C(transition)[T.silence]                                0.1745      0.009     19.869      0.000       0.157       0.192
# C(voc_ctx)[T.vocalization]:C(transition)[T.same]       -0.0130      0.024     -0.551      0.582      -0.059       0.033
# C(voc_ctx)[T.vocalization]:C(transition)[T.silence]    -0.1844      0.031     -5.918      0.000      -0.245      -0.123
# ==============================================================================
# Omnibus:                    47921.554   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1020078.025
# Skew:                           3.264   Prob(JB):                         0.00
# Kurtosis:                      21.032   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# #### last_bin ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     70.07
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):           2.30e-73
# Time:                        13:31:35   Log-Likelihood:                -84255.
# No. Observations:               66571   AIC:                         1.685e+05
# Df Residuals:                   66565   BIC:                         1.686e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.9888      0.005    218.161      0.000       0.980       0.998
# C(voc_ctx)[T.vocalization]                              0.0289      0.010      2.765      0.006       0.008       0.049
# C(transition)[T.same]                                  -0.0011      0.011     -0.103      0.918      -0.023       0.020
# C(transition)[T.silence]                                0.1639      0.009     18.198      0.000       0.146       0.182
# C(voc_ctx)[T.vocalization]:C(transition)[T.same]       -0.0147      0.024     -0.609      0.542      -0.062       0.033
# C(voc_ctx)[T.vocalization]:C(transition)[T.silence]    -0.1220      0.032     -3.817      0.000      -0.185      -0.059
# ==============================================================================
# Omnibus:                    19064.305   Durbin-Watson:                   1.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            44956.055
# Skew:                           1.629   Prob(JB):                         0.00
# Kurtosis:                       5.366   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ######### integral, region #########
#
# KruskalResult(statistic=93.80592795611672, pvalue=3.4802794259140945e-22)
# Dunn post hoc results
#                A1           PEG
# A1   1.000000e+00  3.480279e-22
# PEG  3.480279e-22  1.000000e+00
#
# ######### integral, transition #########
#
# KruskalResult(statistic=422.1311052850962, pvalue=2.1646872914741717e-92)
# Dunn post hoc results
#                  diff          same       silence
# diff     1.000000e+00  3.432724e-07  2.008126e-75
# same     3.432724e-07  1.000000e+00  4.296612e-73
# silence  2.008126e-75  4.296612e-73  1.000000e+00
#
# ######### integral, vocalization #########
#
# KruskalResult(statistic=126.50600826899087, pvalue=2.382792187245118e-29)
# Dunn post hoc results
#                      sound  vocalization
# sound         1.000000e+00  2.382792e-29
# vocalization  2.382792e-29  1.000000e+00
#
# ######### last_bin, region #########
#
# KruskalResult(statistic=132.84548563338066, pvalue=9.77296099397589e-31)
# Dunn post hoc results
#                A1           PEG
# A1   1.000000e+00  9.772961e-31
# PEG  9.772961e-31  1.000000e+00
#
# ######### last_bin, transition #########
#
# KruskalResult(statistic=243.54511960670354, pvalue=1.3027144491221288e-53)
# Dunn post hoc results
#                  diff          same       silence
# diff     1.000000e+00  5.631117e-01  2.354233e-50
# same     5.631117e-01  1.000000e+00  3.403535e-34
# silence  2.354233e-50  3.403535e-34  1.000000e+00
#
# ######### last_bin, vocalization #########
#
# KruskalResult(statistic=110.78616746841305, pvalue=6.591000328667152e-26)
# Dunn post hoc results
#                      sound  vocalization
# sound         1.000000e+00  6.591000e-26
# vocalization  6.591000e-26  1.000000e+00

# %% [markdown]
# # Figure 3
# ## panels A and B

# %%
fig = plot_example_site_coverage()
fig.show(renderer='jpeg', scale=2)
# Out:
# names of sounds used:
#    probe                                named_probe
# 0     1             ferret_fights_Athena-Violet001
# 1     2            colouring_freesound_123jorre456
# 2     3                              flute_bourree
# 3     4  latin-pop_enrique-iglesias_i-will-survive
# Coverage counts:
#                count
# id
# ARM021b-43-8     29
# ARM021b-40-6     27
# ARM021b-36-8     25
# ARM021b-10-4     23
# ARM021b-06-3     15
# ...             ...
# CRD002a-15-2      0
# CRD002a-16-1      0
# CRD002a-16-2      0
# CRD002a-18-1      0
# ley075b-PC-9      0
#
# [2728 rows x 1 columns]
# Plotted neurons:
#  ['ARM021b-06-3', 'ARM021b-10-4', 'ARM021b-36-8', 'ARM021b-40-6', 'ARM021b-43-8', 'ARM021b-53-1', 'PC1', 'Union']

# %% [markdown]
# ## panel C

# %%
fig = plot_neuron_and_site_coverage_summary()
fig.show(renderer='jpeg', scale=2)
# Out:
# ######################################################################
# ############# Comparison between coverage category       #############
# ############# adjusting for matched sample number or not #############
#                pair          stat        pvalue     x_mean     x_sem  \
# 0     SC_vs_best_SC  mannwhitneyu  8.130636e-25  11.202778  0.374160
# 1       SC_vs_union  mannwhitneyu  3.332797e-26  11.202778  0.374160
# 2         SC_vs_PC1  mannwhitneyu  6.701216e-19  11.202778  0.374160
# 3  best_SC_vs_union      wilcoxon  1.135000e-06  41.443261  2.798979
# 4    best_SC_vs_PC1      wilcoxon  1.494963e-05  41.443261  2.798979
# 5      union_vs_PC1      wilcoxon  4.203865e-09  53.409617  3.919799
#
#       y_mean     y_sem  signif
# 0  41.443261  2.798979    True
# 1  53.409617  3.919799    True
# 2  33.539369  2.702664    True
# 3  53.409617  3.919799    True
# 4  33.539369  2.702664    True
# 5  33.539369  2.702664    True
#
# ######################################################################
# ################ Comparison between cortical regions #################
# ################ within each coverage category       #################
#      quant          stat        pvalue     A1mean     A1SEM    PEGmean  \
# 0       SC  mannwhitneyu  1.108220e-07   9.179019  0.438452  14.046216
# 1  best_SC  mannwhitneyu  4.772641e-01  39.841049  3.620778  43.503247
# 2    union  mannwhitneyu  6.502033e-01  51.807753  4.868080  55.469156
# 3      PC1  mannwhitneyu  4.363196e-01  31.438677  3.455331  36.240260
#
#      PEGSEM  signif
# 0  0.641411    True
# 1  4.433214   False
# 2  6.493799   False
# 3  4.310175   False
# best_SC=33.54 PC1=41.44 union=53.41
# SC=11.202778201423186

# %% [markdown]
# # Figure 4
# ## panel A and D

# %%
fig = plot_diagonalization_geometric_example()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel B and E

# %%
fig =plot_example_coverage_with_diagonalization()
fig.show(renderer='jpeg', scale=2)
# Out:
# Plotted neurons:
#  ['ARM021b-36-8', 'ARM021b-43-8', 'dense']

# %% [markdown]
# ## panel C and F

# %%
fig = plot_summary_decoder_accuracies()
fig.show(renderer='jpeg', scale=1)

# %% [markdown]
# # Figure 5
# ## panel A

# %%
# fig = plot_optotagged_example_neuron()
# fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel B

# %%
fig = plot_classified_waveforms()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel C

# %%
fig = plot_cell_type_distributions()
fig.show(renderer='jpeg', scale=2)
# Out:
# waveform threshold. lower: 0.37, upper 0.47

# %% [markdown]
# ## panels D and E

# %%
fig = plot_metric_cumulative_histograms()
fig.show(renderer='jpeg', scale=2)
# Out:
# ######## integral ########
# KruskalResult(statistic=63.20672466613851, pvalue=1.8829298015101073e-14)
# Dunn post hoc results
#            activated         broad        narrow
# activated   1.000000  1.059118e-06  1.314109e-01
# broad       0.000001  1.000000e+00  1.786963e-10
# narrow      0.131411  1.786963e-10  1.000000e+00
#
# ######## last_bin ########
# KruskalResult(statistic=30.27459544161709, pvalue=2.6665831403429457e-07)
# Dunn post hoc results
#            activated         broad        narrow
# activated   1.000000  2.219481e-01  1.000000e+00
# broad       0.221948  1.000000e+00  2.704322e-07
# narrow      1.000000  2.704322e-07  1.000000e+00

# %%
fig = plot_metric_insets()
fig.show(renderer='jpeg', scale=2)
# Out:
# #### integral bar value ####
#              median  SEmedian      mean    SEmean
# triple
# activated  0.169934  0.005676  0.204019  0.003552
# narrow     0.176161  0.002491  0.214651  0.001481
# broad      0.185344  0.001026  0.245317  0.001788
#
# #### last_bin bar value ####
#            median  SEmedian        mean    SEmean
# triple
# activated   200.0       0.0  252.426840  5.767985
# narrow      150.0       0.0  246.015284  2.032029
# broad       200.0       0.0  252.908264  1.833654

# %% [markdown]
# ## panel F

# %%
fig = plot_coverage_cumulative_histogram()
fig.show(renderer='jpeg', scale=2)
# Out:
# ####### non parametric anova with posthoc #######
# KruskalResult(statistic=7.41797435090606, pvalue=0.02450232726699855)
# Dunn post hoc results
#            activated     broad    narrow
# activated   1.000000  1.000000  0.235344
# broad       1.000000  1.000000  0.022503
# narrow      0.235344  0.022503  1.000000

# %%
fig = plot_coverage_inset()
fig.show(renderer='jpeg', scale=2)
# Out:
# ##### Context coverage bar values #####
#            coverage     error
# triple
# activated  2.000000  0.626680
# narrow     3.916364  1.105458
# broad      2.148182  0.595277

# %% [markdown]
# # Figure 6
# ## panel A

# %%
fig = plot_encoding_model_schematic()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel B

# %%
fig = plot_example_model_predictions()
fig.show(renderer='jpeg', scale=2)
# Out:
# Warning: smoothing the data. Smooth only for display and not for analysis
# Warning: smoothing the data. Smooth only for display and not for analysis

# %% [markdown]
# ## panel C

# %%
# fig = plot_relative_model_performance()
# fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## panel D

# %%
fig = plot_context_effect_prediction_scatter()
fig.show(renderer='jpeg', scale=2)
# Out:
# #### measured vs predicted context effects correlation ####
# A, matchl_STRF, R2=-0.5983234872414029, r=0.4921373901082613, pvalue=0.0
# A, matchl_full, R2=-0.07640586516500036, r=0.6250678286860144, pvalue=0.0
# B, matchl_STRF, R2=-0.6288761391279125, r=0.40506701598283235, pvalue=0.0
# B, matchl_full, R2=0.08917797219695689, r=0.6607060702789449, pvalue=0.0
# C, matchl_STRF, R2=-0.5672051745526001, r=0.37490099029137425, pvalue=0.0
# C, matchl_full, R2=-0.17414740281172425, r=0.6251585441580597, pvalue=0.0

# %% [markdown]
# ## panel E

# %%
fig = plot_summary_model_performance_bars()
fig.show(renderer='jpeg', scale=2)
# Out:
# #### Number of Neurons Modeled ####
#  243
# #### Number of regressed instances ####
#  16183
#
# #### paiwise statistical test within time bins ####
#                                         stat        pvalue     corr_pval  \
# time_bin model_1     model_2
# A        matchl_STRF matchl_self  -2.507775  1.719037e-02  1.031422e-01
#                      matchl_pop   -6.136314  2.656879e-09  1.594127e-08
#                      matchl_full  -7.319498  9.273293e-13  5.563976e-12
#          matchl_self matchl_pop   -3.812387  2.785018e-04  1.671011e-03
#                      matchl_full  -4.883289  2.646704e-06  1.588022e-05
#          matchl_pop  matchl_full  -0.798137  2.901231e-01  1.740739e+00
# B        matchl_STRF matchl_self  -7.120751  3.894381e-12  2.336629e-11
#                      matchl_pop   -8.761511  8.546826e-18  5.128096e-17
#                      matchl_full -12.635266  8.577629e-36  5.146577e-35
#          matchl_self matchl_pop   -1.399281  1.498782e-01  8.992691e-01
#                      matchl_full  -4.655431  7.846373e-06  4.707824e-05
#          matchl_pop  matchl_full  -3.268138  1.912579e-03  1.147548e-02
# C        matchl_STRF matchl_self  -9.917381  1.751923e-22  1.051154e-21
#                      matchl_pop   -7.126543  3.736961e-12  2.242176e-11
#                      matchl_full -11.314967  6.307810e-29  3.784686e-28
#          matchl_self matchl_pop    3.613094  5.836764e-04  3.502058e-03
#                      matchl_full  -1.697315  9.447902e-02  5.668741e-01
#          matchl_pop  matchl_full  -5.449391  1.420810e-07  8.524863e-07
# D        matchl_STRF matchl_self  -8.718215  1.247787e-17  7.486719e-17
#                      matchl_pop   -6.584380  1.537080e-10  9.222479e-10
#                      matchl_full  -9.981630  9.244654e-23  5.546792e-22
#          matchl_self matchl_pop    2.363641  2.442037e-02  1.465222e-01
#                      matchl_full  -1.160659  2.034158e-01  1.220495e+00
#          matchl_pop  matchl_full  -3.603851  6.034735e-04  3.620841e-03
#
#                                    0.05   0.01  0.001
# time_bin model_1     model_2
# A        matchl_STRF matchl_self  False  False  False
#                      matchl_pop    True   True   True
#                      matchl_full   True   True   True
#          matchl_self matchl_pop    True   True  False
#                      matchl_full   True   True   True
#          matchl_pop  matchl_full  False  False  False
# B        matchl_STRF matchl_self   True   True   True
#                      matchl_pop    True   True   True
#                      matchl_full   True   True   True
#          matchl_self matchl_pop   False  False  False
#                      matchl_full   True   True   True
#          matchl_pop  matchl_full   True  False  False
# C        matchl_STRF matchl_self   True   True   True
#                      matchl_pop    True   True   True
#                      matchl_full   True   True   True
#          matchl_self matchl_pop    True   True  False
#                      matchl_full  False  False  False
#          matchl_pop  matchl_full   True   True   True
# D        matchl_STRF matchl_self   True   True   True
#                      matchl_pop    True   True   True
#                      matchl_full   True   True   True
#          matchl_self matchl_pop   False  False  False
#                      matchl_full  False  False  False
#          matchl_pop  matchl_full   True   True  False

# %% [markdown]
# # Table 1
# sounds names with 3 metrics and spectrogram

# %%
fig = create_sound_analysis_table()
fig.show(renderer='jpeg', scale=2)
# Out:
#                                          name  bandwidth  \
# 0                               cash register       3.87
# 1             colouring freesound 123jorre456       4.21
# 2                              factory sounds       5.89
# 3              ferret fights Athena Violet001       1.85
# 4             ferret fights Jasmine Violet001       3.87
# 5             fiddle luke abbott willie moore       3.20
# 6                               flute bourree       2.02
# 7                                    giggling       3.36
# 8                                 grunt groan       3.20
# 9   latin pop enrique iglesias i will survive       5.22
# 10                pop kelly clarkson einstein       5.22
# 11                             pouring cereal       3.53
# 12                                    shaving       3.36
# 13                                 tambourine       1.85
# 14                              toothbrushing       2.52
# 15                              window blinds       3.20
#
#     temporal_stationarity  spectral_correlations
# 0                   40.94                   0.55
# 1                   22.73                   0.57
# 2                   24.31                   0.67
# 3                   79.69                   0.72
# 4                   52.23                   0.66
# 5                   27.66                   0.37
# 6                   76.85                   0.26
# 7                   58.98                   0.64
# 8                   49.28                   0.77
# 9                   29.43                   0.28
# 10                  26.76                   0.17
# 11                  45.02                   0.56
# 12                  37.37                   0.88
# 13                  68.62                   0.94
# 14                  63.60                   0.53
# 15                  35.98                   0.83

# %% [markdown]
# # supplementary figure 1
# ## panel A

# %%
fig = plot_context_metric_correlation_significance()
fig.show(renderer='jpeg', scale=2)
# Out:
# ##### R null distribution mean and SEM #####
#  0.2916013019585175 0.000850319476425152
# ##### Measured R value #####
#  0.4797114930007204

# %% [markdown]
# ## panels B and C
# effect of probe vocalization on context effects

# %%
print_probe_voc_regression()
fig = plot_metric_by_probe_vocalization()
fig.show(renderer='jpeg', scale=2)
# Out:
# ####### Linear regression by vocalization if in probe #######
#
#
# #### integral ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.752
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):             0.0527
# Time:                        13:32:25   Log-Likelihood:                -55027.
# No. Observations:               45906   AIC:                         1.101e+05
# Df Residuals:                   45904   BIC:                         1.101e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.0024      0.004    254.510      0.000       0.995       1.010
# C(voc_prb)[T.vocalization]    -0.0246      0.013     -1.937      0.053      -0.050       0.000
# ==============================================================================
# Omnibus:                    32512.138   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           676859.247
# Skew:                           3.192   Prob(JB):                         0.00
# Kurtosis:                      20.695   Cond. No.                         3.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# #### last_bin ####
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               norm_val   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.485
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):              0.223
# Time:                        13:32:25   Log-Likelihood:                -56988.
# No. Observations:               45906   AIC:                         1.140e+05
# Df Residuals:                   45904   BIC:                         1.140e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.0016      0.004    243.671      0.000       0.993       1.010
# C(voc_prb)[T.vocalization]    -0.0162      0.013     -1.219      0.223      -0.042       0.010
# ==============================================================================
# Omnibus:                    13869.192   Durbin-Watson:                   1.534
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34859.714
# Skew:                           1.682   Prob(JB):                         0.00
# Kurtosis:                       5.629   Cond. No.                         3.43
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ##### mean and error values by vocalization #####
# integral mean±SEM. sound: 0.24±0.0009, vocalization: 0.23±0.0030 Z-score*s
# last_bin mean±SEM. sound: 249.64±1.0281, vocalization: 245.61±3.0393 ms
#
# ######### integral voc_prb #########
#
# KruskalResult(statistic=26.001541997910866, pvalue=3.411447707770549e-07)
# Dunn post hoc results
#                      sound  vocalization
# sound         1.000000e+00  3.411448e-07
# vocalization  3.411448e-07  1.000000e+00
#
# data summary stats
#                    stat       err  count
# voc_prb
# sound         0.237010  0.000926  41502
# vocalization  0.231186  0.003010   4404
#
# ######### last_bin voc_prb #########
#
# KruskalResult(statistic=0.008835579747539153, pvalue=0.9251109324757422)
# Dunn post hoc results
#                  sound  vocalization
# sound         1.000000      0.925111
# vocalization  0.925111      1.000000
#
# data summary stats
#                      stat       err  count
# voc_prb
# sound         249.637360  1.028072  41502
# vocalization  245.606262  3.039282   4404

# %% [markdown]
# ## panels D and E
# effect of cortical layer on context effects

# %%
fig = plot_layer_effect_on_context_metrics()
fig.show(renderer='jpeg', scale=2)
# Out:
# 868 neurons labeled by layer
#        count
# layer
# 1-3      427
# 4        220
# 5-6      221
#
# #### integral ####
# KruskalResult(statistic=187.1659955329914, pvalue=2.2773011740657092e-41)
# Dunn post hoc results
#               1-3             4           5-6
# 1-3  1.000000e+00  1.243248e-39  9.777817e-11
# 4    1.243248e-39  1.000000e+00  1.791436e-06
# 5-6  9.777817e-11  1.791436e-06  1.000000e+00
# summary stats
#         count      stat       err
# layer
# 1-3    40354  0.241516  0.001037
# 4      14725  0.258317  0.001652
# 5-6    12800  0.234679  0.001382
#
#
# #### last_bin ####
# KruskalResult(statistic=8.94921840111966, pvalue=0.011394674286837657)
# Dunn post hoc results
#           1-3         4       5-6
# 1-3  1.000000  0.284044  0.144479
# 4    0.284044  1.000000  0.008366
# 5-6  0.144479  0.008366  1.000000
# summary stats
#         count        stat       err
# layer
# 1-3    40354  245.597717  0.994588
# 4      14725  257.633270  1.768632
# 5-6    12800  237.500000  1.660805

# %% [markdown]
# # Supplementary Figure 2
# ## panels A and B
# note the legend is covering the last panel, but it can be easily edited if exported as .svg

# %%
fig = plot_exmaple_pupil_psths()
fig.show(renderer='jpeg',scale=2)

# %% [markdown]
# ## panel C

# %%
fig = plot_first_vs_second_order_effects() 
fig.show(renderer='jpeg', scale=2)
# Out:
# ###########
# chunk A, n_neuron=776, n_instanceses=12868
# mean MI: first_ord=0.05744515731930733, second_ord0.016472590502883938
# FR_MI: Ttest_1sampResult(statistic=38.93645540074866, pvalue=0.0)
# ctx_MI: Ttest_1sampResult(statistic=8.911581505310462, pvalue=5.701397036504273e-19)
# first vs second order modulation index:
# LinregressResult(slope=0.22426272924409751, intercept=0.003589782740599533, rvalue=0.17899751756713206, pvalue=4.1091512841505865e-93, stderr=0.010867183540217668, intercept_stderr=0.0019228237715060764)
# 2000
#
# ###########
# chunk B, n_neuron=513, n_instanceses=4942
# mean MI: first_ord=0.06500754505395889, second_ord0.0012587882782037574
# FR_MI: Ttest_1sampResult(statistic=27.54461568884392, pvalue=1.6922510034290816e-155)
# ctx_MI: Ttest_1sampResult(statistic=0.3538708609342707, pvalue=0.7234507643474588)
# first vs second order modulation index:
# LinregressResult(slope=0.16970742290924853, intercept=-0.009773474662560473, rvalue=0.112595230716621, pvalue=2.044343427349602e-15, stderr=0.02130820395840186, intercept_stderr=0.003796646054057842)
# 2000
#
# ###########
# chunk C, n_neuron=298, n_instanceses=1815
# mean MI: first_ord=0.06957375258207321, second_ord-0.019721260697432935
# FR_MI: Ttest_1sampResult(statistic=18.636600024744915, pvalue=4.587859113288084e-71)
# ctx_MI: Ttest_1sampResult(statistic=-3.5290383749881498, pvalue=0.0004274674022397344)
# first vs second order modulation index:
# LinregressResult(slope=-0.021192776402583945, intercept=-0.01824679971547236, rvalue=-0.014157556919922105, pvalue=0.5466640450091653, stderr=0.03515257221311604, intercept_stderr=0.006100924977403384)
# decimation end number greater than data, returning unchaged data
# 1815
#
# ###########
# chunk D, n_neuron=170, n_instanceses=668
# mean MI: first_ord=0.07907646149396896, second_ord-0.04261620095272551
# FR_MI: Ttest_1sampResult(statistic=11.9038726669574, pvalue=9.191335489939317e-30)
# ctx_MI: Ttest_1sampResult(statistic=-4.511325091815377, pvalue=7.612734852695161e-06)
# first vs second order modulation index:
# LinregressResult(slope=-0.04896830522872598, intercept=-0.03874396064988124, rvalue=-0.03443526489697582, pvalue=0.37421805202555336, stderr=0.05507022964381913, intercept_stderr=0.010403276863080554)
# decimation end number greater than data, returning unchaged data
# 668

# %% [markdown]
# ## panel D

# %%
fig = plot_sound_effect_on_pupil()
fig.show(renderer='jpeg', scale=2)
# Out:
# ######### statisitic for context_name effect on pupil #########
#
# KruskalResult(statistic=155.49660974612198, pvalue=6.414046467245083e-25)
# Dunn post hoc results
#                      USA pop  cash register  coloring  factory sounds  \
# USA pop         1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# cash register   1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# coloring        1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# factory sounds  1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# ferret fight 1  5.056072e-03   5.720318e-01  1.000000    7.021773e-04
# ferret fight 2  1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# fiddle          1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# flute           1.000000e+00   1.000000e+00  1.000000    1.000000e+00
# giggling        1.000000e+00   1.000000e+00  1.000000    6.170180e-01
# grunt groan     1.000000e+00   1.000000e+00  1.000000    2.024138e-01
# latin pop       1.000000e+00   7.073707e-02  0.242619    1.000000e+00
# pouring cereal  1.000000e+00   1.000000e+00  1.000000    2.773846e-01
# shaving         1.000000e+00   1.000000e+00  1.000000    4.535906e-01
# silence         4.869556e-14   1.086939e-09  0.000002    5.961751e-13
# tambourine      2.667091e-02   1.000000e+00  1.000000    3.165002e-03
# toothbrushing   1.000000e+00   1.000000e+00  1.000000    3.923530e-01
# window blinds   1.000000e+00   1.000000e+00  1.000000    1.000000e+00
#
#                 ferret fight 1  ferret fight 2        fiddle         flute  \
# USA pop           5.056072e-03        1.000000  1.000000e+00  1.000000e+00
# cash register     5.720318e-01        1.000000  1.000000e+00  1.000000e+00
# coloring          1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# factory sounds    7.021773e-04        1.000000  1.000000e+00  1.000000e+00
# ferret fight 1    1.000000e+00        1.000000  9.376168e-01  9.150911e-01
# ferret fight 2    1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# fiddle            9.376168e-01        1.000000  1.000000e+00  1.000000e+00
# flute             9.150911e-01        1.000000  1.000000e+00  1.000000e+00
# giggling          1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# grunt groan       1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# latin pop         3.816822e-07        0.375490  1.000000e+00  1.436303e-01
# pouring cereal    1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# shaving           1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# silence           4.408628e-02        0.008321  7.948774e-07  2.460682e-08
# tambourine        1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# toothbrushing     1.000000e+00        1.000000  1.000000e+00  1.000000e+00
# window blinds     2.484213e-01        1.000000  1.000000e+00  1.000000e+00
#
#                 giggling  grunt groan     latin pop  pouring cereal   shaving  \
# USA pop         1.000000     1.000000  1.000000e+00        1.000000  1.000000
# cash register   1.000000     1.000000  7.073707e-02        1.000000  1.000000
# coloring        1.000000     1.000000  2.426189e-01        1.000000  1.000000
# factory sounds  0.617018     0.202414  1.000000e+00        0.277385  0.453591
# ferret fight 1  1.000000     1.000000  3.816822e-07        1.000000  1.000000
# ferret fight 2  1.000000     1.000000  3.754900e-01        1.000000  1.000000
# fiddle          1.000000     1.000000  1.000000e+00        1.000000  1.000000
# flute           1.000000     1.000000  1.436303e-01        1.000000  1.000000
# giggling        1.000000     1.000000  6.276948e-03        1.000000  1.000000
# grunt groan     1.000000     1.000000  3.022065e-03        1.000000  1.000000
# latin pop       0.006277     0.003022  1.000000e+00        0.005235  0.006570
# pouring cereal  1.000000     1.000000  5.234943e-03        1.000000  1.000000
# shaving         1.000000     1.000000  6.570447e-03        1.000000  1.000000
# silence         0.000004     0.022429  1.010102e-19        0.030684  0.000602
# tambourine      1.000000     1.000000  8.118350e-06        1.000000  1.000000
# toothbrushing   1.000000     1.000000  6.811372e-03        1.000000  1.000000
# window blinds   1.000000     1.000000  4.007660e-01        1.000000  1.000000
#
#                      silence  tambourine  toothbrushing  window blinds
# USA pop         4.869556e-14    0.026671       1.000000   1.000000e+00
# cash register   1.086939e-09    1.000000       1.000000   1.000000e+00
# coloring        1.993721e-06    1.000000       1.000000   1.000000e+00
# factory sounds  5.961751e-13    0.003165       0.392353   1.000000e+00
# ferret fight 1  4.408628e-02    1.000000       1.000000   2.484213e-01
# ferret fight 2  8.320694e-03    1.000000       1.000000   1.000000e+00
# fiddle          7.948774e-07    1.000000       1.000000   1.000000e+00
# flute           2.460682e-08    1.000000       1.000000   1.000000e+00
# giggling        3.912060e-06    1.000000       1.000000   1.000000e+00
# grunt groan     2.242938e-02    1.000000       1.000000   1.000000e+00
# latin pop       1.010102e-19    0.000008       0.006811   4.007660e-01
# pouring cereal  3.068381e-02    1.000000       1.000000   1.000000e+00
# shaving         6.018816e-04    1.000000       1.000000   1.000000e+00
# silence         1.000000e+00    0.435123       0.004615   8.169281e-10
# tambourine      4.351227e-01    1.000000       1.000000   5.671977e-01
# toothbrushing   4.614613e-03    1.000000       1.000000   1.000000e+00
# window blinds   8.169281e-10    0.567198       1.000000   1.000000e+00
#
# data summary stats
#        context_name      stat       err  count
# 0          silence -0.064159  0.007226    407
# 1       tambourine -0.019626  0.011558    175
# 2   ferret fight 1 -0.018041  0.009183    282
# 3      grunt groan -0.005985  0.013610    145
# 4    toothbrushing -0.002667  0.014634    154
# 5   pouring cereal -0.000966  0.013316    134
# 6          shaving  0.009200  0.014327    181
# 7   ferret fight 2  0.009481  0.015665     96
# 8         giggling  0.010143  0.010156    256
# 9         coloring  0.020503  0.012426    181
# 10   cash register  0.020579  0.009222    315
# 11           flute  0.020859  0.009884    246
# 12   window blinds  0.023509  0.010325    259
# 13          fiddle  0.027749  0.012922    156
# 14         USA pop  0.042366  0.009337    299
# 15  factory sounds  0.055613  0.013241    163
# 16       latin pop  0.072413  0.011905    203
#
# ######### statisitic for probe_name effect on pupil #########
#
# KruskalResult(statistic=43.39630912096618, pvalue=0.0001366218604077651)
# Dunn post hoc results
#                  USA pop  cash register  coloring  factory sounds  \
# USA pop         1.000000       1.000000       1.0        1.000000
# cash register   1.000000       1.000000       1.0        1.000000
# coloring        1.000000       1.000000       1.0        1.000000
# factory sounds  1.000000       1.000000       1.0        1.000000
# ferret fight 1  1.000000       0.804921       1.0        0.026992
# ferret fight 2  1.000000       1.000000       1.0        1.000000
# fiddle          1.000000       1.000000       1.0        0.310920
# flute           1.000000       1.000000       1.0        1.000000
# giggling        1.000000       1.000000       1.0        0.353526
# grunt groan     1.000000       1.000000       1.0        1.000000
# latin pop       0.315248       1.000000       1.0        1.000000
# pouring cereal  1.000000       1.000000       1.0        0.921415
# shaving         1.000000       1.000000       1.0        1.000000
# tambourine      1.000000       1.000000       1.0        0.114871
# toothbrushing   1.000000       1.000000       1.0        0.554091
# window blinds   1.000000       1.000000       1.0        1.000000
#
#                 ferret fight 1  ferret fight 2    fiddle     flute  giggling  \
# USA pop               1.000000             1.0  1.000000  1.000000  1.000000
# cash register         0.804921             1.0  1.000000  1.000000  1.000000
# coloring              1.000000             1.0  1.000000  1.000000  1.000000
# factory sounds        0.026992             1.0  0.310920  1.000000  0.353526
# ferret fight 1        1.000000             1.0  1.000000  1.000000  1.000000
# ferret fight 2        1.000000             1.0  1.000000  1.000000  1.000000
# fiddle                1.000000             1.0  1.000000  1.000000  1.000000
# flute                 1.000000             1.0  1.000000  1.000000  1.000000
# giggling              1.000000             1.0  1.000000  1.000000  1.000000
# grunt groan           1.000000             1.0  1.000000  1.000000  1.000000
# latin pop             0.001868             1.0  0.057962  0.317813  0.048747
# pouring cereal        1.000000             1.0  1.000000  1.000000  1.000000
# shaving               1.000000             1.0  1.000000  1.000000  1.000000
# tambourine            1.000000             1.0  1.000000  1.000000  1.000000
# toothbrushing         1.000000             1.0  1.000000  1.000000  1.000000
# window blinds         0.615966             1.0  1.000000  1.000000  1.000000
#
#                 grunt groan  latin pop  pouring cereal  shaving  tambourine  \
# USA pop                 1.0   0.315248        1.000000      1.0    1.000000
# cash register           1.0   1.000000        1.000000      1.0    1.000000
# coloring                1.0   1.000000        1.000000      1.0    1.000000
# factory sounds          1.0   1.000000        0.921415      1.0    0.114871
# ferret fight 1          1.0   0.001868        1.000000      1.0    1.000000
# ferret fight 2          1.0   1.000000        1.000000      1.0    1.000000
# fiddle                  1.0   0.057962        1.000000      1.0    1.000000
# flute                   1.0   0.317813        1.000000      1.0    1.000000
# giggling                1.0   0.048747        1.000000      1.0    1.000000
# grunt groan             1.0   1.000000        1.000000      1.0    1.000000
# latin pop               1.0   1.000000        0.231428      1.0    0.016206
# pouring cereal          1.0   0.231428        1.000000      1.0    1.000000
# shaving                 1.0   1.000000        1.000000      1.0    1.000000
# tambourine              1.0   0.016206        1.000000      1.0    1.000000
# toothbrushing           1.0   0.116688        1.000000      1.0    1.000000
# window blinds           1.0   1.000000        1.000000      1.0    1.000000
#
#                 toothbrushing  window blinds
# USA pop              1.000000       1.000000
# cash register        1.000000       1.000000
# coloring             1.000000       1.000000
# factory sounds       0.554091       1.000000
# ferret fight 1       1.000000       0.615966
# ferret fight 2       1.000000       1.000000
# fiddle               1.000000       1.000000
# flute                1.000000       1.000000
# giggling             1.000000       1.000000
# grunt groan          1.000000       1.000000
# latin pop            0.116688       1.000000
# pouring cereal       1.000000       1.000000
# shaving              1.000000       1.000000
# tambourine           1.000000       1.000000
# toothbrushing        1.000000       1.000000
# window blinds        1.000000       1.000000
#
# data summary stats
#          probe_name      stat       err  count
# 0   ferret fight 1 -0.015986  0.008865    322
# 1       tambourine -0.012211  0.010769    196
# 2           fiddle -0.006631  0.011966    175
# 3    toothbrushing -0.005492  0.013261    173
# 4   pouring cereal -0.003953  0.012998    152
# 5         giggling -0.003145  0.009144    290
# 6            flute  0.000644  0.009170    277
# 7      grunt groan  0.001200  0.014888    162
# 8          USA pop  0.009375  0.009158    335
# 9   ferret fight 2  0.012537  0.015080    111
# 10   cash register  0.016161  0.008681    355
# 11         shaving  0.018938  0.013734    207
# 12        coloring  0.021307  0.011719    201
# 13   window blinds  0.022055  0.010043    288
# 14  factory sounds  0.039365  0.011754    181
# 15       latin pop  0.044696  0.010637    227

# %% [markdown]
# ## Regressions
# of sound descriptive metrics to pupil size

# %%
print_sound_metrics_correlation_to_pupil()
# Out:
# correlations of prior (context_name) and current (probe_name) sound metrics to pupil size:
#
# context_name
#     temporal_stationarity
#     R=-0.104, p=0.000
#     bandwidth
#     R=0.121, p=0.000
#     spectral_correlations
#     R=-0.088, p=0.000
# probe_name
#     temporal_stationarity
#     R=-0.074, p=0.000
#     bandwidth
#     R=0.079, p=0.000
#     spectral_correlations
#     R=-0.015, p=0.357

# %% [markdown]
# # Suppementary figure 3
# ## panel A
# cumulative variance explained of sites PCA

# %%
fig = plot_cumulative_variances_explained()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# # panel B
# example context coverage of first and last principal components

# %%
fig = plot_example_pca_coverages()
fig.show(renderer='jpeg', scale=2)
# Out:
# Plotted neurons:
#  ['ARM021b-PC-1', 'ARM021b-PC-2', 'ARM021b-PC-3', 'ARM021b-PC-4', 'ARM021b-PC-17', 'ARM021b-PC-18', 'ARM021b-PC-19', 'ARM021b-PC-20']

# %% [markdown]
# # Supplementary Figure 4
# ## panels A to D
# extended description of decoders for 10 and 4 sound datasets

# %%
fig = plot_decoder_analysis_by_nsounds_and_region()
fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# # Supplemenatry Figure 6
# # Panel A
# absolute model performances

# %%
# fig = plot_absolute_model_performances()
# fig.show(renderer='jpeg', scale=2)

# %% [markdown]
# ## Panel B
# STRF weights over time

# %%
fig = plot_strf_average_weights_over_time()
fig.show(renderer='jpeg', scale=2)
# Out:
# Plotting weights for 314 model fits

# %% [markdown]
# ## Panel C
# neuron connection weights by cell types

# %%
fig = plot_connection_weigths_by_cell_type()
fig.show(renderer='jpeg', scale=2)
# Out:
# ######### sender_type #########
# KruskalResult(statistic=24.30973966698366, pvalue=5.262681693390516e-06)
# Dunn post hoc results
#            activated     broad    narrow
# activated    1.00000  0.000050  0.063530
# broad        0.00005  1.000000  0.016495
# narrow       0.06353  0.016495  1.000000
# summary statistics
#               count      stat       err
# sender_type
# activated      568  0.004664  0.002768
# broad         9702 -0.009354  0.000988
# narrow        1654 -0.002758  0.001984
# unclass          0       NaN       NaN
#
# ######### receiver_type #########
#
# KruskalResult(statistic=11.358328511894797, pvalue=0.003416412497025757)
# Dunn post hoc results
#            activated     broad    narrow
# activated     1.0000  0.145100  1.000000
# broad         0.1451  1.000000  0.011279
# narrow        1.0000  0.011279  1.000000
# summary statistics
#                 count      stat       err
# receiver_type
# activated        568 -0.002989  0.003049
# broad           9702 -0.009170  0.000990
# narrow          1654 -0.001207  0.001909
# unclass            0       NaN       NaN
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:222: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:222: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning:
#
# invalid value encountered in true_divide

# %% [markdown]
# ## Stats for self connections
# No significant differences between cell types, data not shown.

# %%
_ = print_self_weights_statistics()
# Out:
# KruskalResult(statistic=0.7361559290260402, pvalue=0.6920632232131576)
# Dunn post hoc results
#            activated  broad  narrow
# activated        1.0    1.0     1.0
# broad            1.0    1.0     1.0
# narrow           1.0    1.0     1.0
#
# Summary statistics
#                 count      stat       err
# receiver_type
# activated         15  0.176946  0.025573
# broad            236  0.169681  0.009851
# narrow            46  0.147548  0.015349
# unclass            0       NaN       NaN
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:262: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:222: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /home/mateo/miniconda3/envs/context_probe_analysis/lib/python3.9/site-packages/numpy/core/_methods.py:254: RuntimeWarning:
#
# invalid value encountered in true_divide
